# %%
from tensorflow import keras
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

from sklearn.model_selection import train_test_split
train_scaled = train_input / 255.0
train_scaled = train_scaled.reshape(-1, 28*28)
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size = 0.2, random_state = 42)

dense1 = keras.layers.Dense(100, activation ='sigmoid', input_shape =(784,))      #은닉층 -> sigmoid 함수
dense2 = keras.layers.Dense(10, activation ='softmax')          #출력층 -> softmax 함수

model = keras.Sequential([dense1, dense2])

'''
모델 생성과 동시에 층 추가하는 방식 (1)
model = keras.Sequnetial([keras.layers.Dense(100, activation ='sigmoid', input_shape =(784,)),
 keras.layers.Dense(10, activation = 'softmax')], name = '패션 MNIST 모델')

모델 생성과 동시에 층 추가하는 방식 (2)

model = keras.Sequential()
model.add(keras.layers.Dense(100, activation = 'sigmoid', input_shape = (784, )))
model.add(keras.layers.Dense(10, activation = 'softmax'))

'''

model.compile(loss= 'sparse_categorical_crossentropy', metrics= 'accuracy')
model.fit(train_scaled, train_target, epochs = 5)

model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape =(28, 28)))
model.add(keras.layers.Dense(100, activation = 'relu'))
model.add(keras.layers.Dense(10, activation = 'softmax'))

from tensorflow import keras
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

from sklearn.model_selection import train_test_split
train_scaled = train_input / 255.0                                  #Flatten 클래스로 입력데이터를 일렬로 나열 했으므로 reshape 메서드를 사용 X
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size = 0.2, random_state = 42)

model.compile(loss= 'sparse_categorical_crossentropy', metrics= 'accuracy')
model.fit(train_scaled, train_target, epochs = 5)

model.complie(optimizer = 'sgd', loss = 'sparse_categorical_crossentropy', metrics ='accuracy')
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5679 - accuracy: 0.8045
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4114 - accuracy: 0.8513
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3776 - accuracy: 0.8631
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3540 - accuracy: 0.8733
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3371 - accuracy: 0.8780
# Epoch 1/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5388 - accuracy: 0.8116
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3958 - accuracy: 0.8584
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3550 - accuracy: 0.8726
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3323 - accuracy: 0.8798
# Epoch 5/5
# ...
